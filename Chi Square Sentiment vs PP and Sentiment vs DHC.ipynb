# %%
# Creating a sample data frame
import pandas as pd

excel_file="Chi Square Analysis.xlsx"
df=pd.read_excel(excel_file, sheet_name='Sentiment vs PP vs DHC', usecols = 'A:G')


#print(df.shape)

df.head()

#psychological preparedness vs sentiment
#CrosstabResult=pd.crosstab(index=df['Categorical PP'],columns=df['Sentiment'])
#print(CrosstabResult)


#Categorical DHC vs sentiment
CrosstabResult=pd.crosstab(index=df['Categorical DHC'],columns=df['Sentiment'])
print(CrosstabResult)



"""
ColumnNames=['CIBIL','AGE','GENDER' ,'SALARY', 'APPROVE_LOAN']
DataValues=[ [480, 28, 'M', 610000, 'Yes'],
             [480, 42, 'M',140000, 'No'],
             [480, 29, 'F',420000, 'No'],
             [490, 30, 'M',420000, 'No'],
             [500, 27, 'M',420000, 'No'],
             [510, 34, 'F',190000, 'No'],
             [550, 24, 'M',330000, 'Yes'],
             [560, 34, 'M',160000, 'Yes'],
             [560, 25, 'F',300000, 'Yes'],
             [570, 34, 'M',450000, 'Yes'],
             [590, 30, 'F',140000, 'Yes'],
             [600, 33, 'M',600000, 'Yes'],
             [600, 22, 'M',400000, 'Yes'],
             [600, 25, 'F',490000, 'Yes'],
             [610, 32, 'M',120000, 'Yes'],
             [630, 29, 'F',360000, 'Yes'],
             [630, 30, 'M',480000, 'Yes'],
             [660, 29, 'F',460000, 'Yes'],
             [700, 32, 'M',470000, 'Yes'],
             [740, 28, 'M',400000, 'Yes']]
 
#Create the Data Frame
LoanData=pd.DataFrame(data=DataValues,columns=ColumnNames)
#print(LoanData.head())


#########################################################
# Cross tabulation between GENDER and APPROVE_LOAN
CrosstabResult_practice=pd.crosstab(index=LoanData['GENDER'],columns=LoanData['APPROVE_LOAN'])
print(CrosstabResult_practice)

"""
# importing the required function
from scipy.stats import chi2_contingency
 
# Performing Chi-sq test
#ChiSqResult = chi2_contingency(CrosstabResult)


ChiSqResult = chi2_contingency(CrosstabResult)
 
# P-Value is the Probability of H0 being True
# If P-Value&gt;0.05 then only we Accept the assumption(H0)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])


#Chi-square test between two categorical variables to find the correlation
#H0: The variables are not correlated with each other. 
#This is the H0 used in the Chi-square test.

#In the above example, the P-value came higher than 0.05. 
#Hence H0 will be accepted. Which means the variables are not correlated with each other.

#(same thing: if H0: is correlated then for p>0.5 we reject H0)

#0.00000048
#0.000000000212   3.1253005854612535e-10



"""

#approach 2 to verify the above resutls

# defining the table

#data=[[psy preparedness data], [digital health compentency data]]

#data= [ [expert, proficient, competenent, advance, beginer counts for PP], 
#[expert, proficient, competenent, advance, beginer coutts for DHC]]

data = [[101, 402, 178, 18, 3], [37, 180, 360, 112, 13]]
stat, p, dof, expected = chi2_contingency(data)
  
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')


#6.044189013675124e-53 
#0.0000000000000000000000000000000000000000000000000000604

#so both method give similar results, there fore our experiment design is accurate
"""
# Out:
# Sentiment        Negative  Neutral  Positive
# Categorical DHC
# Advanced               23        5        84
# Beginner                4        0         8
# Competent              33       11       316
# Expert                  5        0        32
# Proficient             19        1       160
# The P-Value of the ChiSq Test is: 0.003549509266909832
# ...
