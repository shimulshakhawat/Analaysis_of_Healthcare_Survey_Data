# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt


"""
# Import Data
excel_file="Chi Square Analysis.xlsx"
df=pd.read_excel(excel_file, sheet_name='calculation', usecols = 'A:K')
print(df.shape)
df.head()

count=0
cat=0

for i in range(df.shape[0]):
    
    score=(df['Psychological preparedness'].iloc[i])
    #score=(df['Digital health competency'].iloc[i])
  
    if score>=0.80:
        cat='Expert'
        count=count+1
        
    elif score>=0.60 and score<0.80:
        cat='Proficient'
        #cat=4
                
    elif score>=0.40 and score<0.60:
        cat='Competent'
        #cat=3
            
    elif score>=0.20 and score<0.40:
        cat='Advanced'
        #cat=2
        
    else: 
        cat='Beginner'
        #cat=1
        
    
    #count=count+1

    #print(cat)
    #print("{}:{}".format(score,cat))
                   
    
print(count)

"""

"""
# Import Data
excel_file="Potential of workforce.xlsx"
df=pd.read_excel(excel_file, sheet_name='calculation', usecols = 'A:K')
#print(df.shape)
#df.head()

count=0
cat=0

for i in range(df.shape[0]):
    
    gender=str(df['Gender'].iloc[i])
    
    if gender=='Female':
    
        score=(df['Psychological preparedness'].iloc[i])

        if score>=0.80:
            cat='Expert'
            #count=count+1

        elif score>=0.60 and score<0.80:
            cat='Proficient'
            #cat=4

        elif score>=0.40 and score<0.60:
            cat='Competent'
            #cat=3

        elif score>=0.20 and score<0.40:
            cat='Advanced'
            #cat=2

        else: 
            cat='Beginner'
            #cat=1


        count=count+1

        print(cat)
        #print("{}:{}".format(score,cat))

    
print(count)
"""

"""
# Import Data
excel_file="Sentiments Analaysis.xlsx"
df=pd.read_excel(excel_file, sheet_name='calculation', usecols = 'A:N')
#print(df.shape)
#df.head()

count=0
cat=0

for i in range(df.shape[0]):
    
    gender=str(df['Gender'].iloc[i])
    
    if gender=='Male':
    
        comment=str(df['Color trinary'].iloc[i])
        
        count=count+1

        print(comment)
        #print("{}:{}".format(score,cat))

    
print(count)

"""


"""
# Import Data
excel_file="Potential of workforce.xlsx"
df=pd.read_excel(excel_file, sheet_name='calculation', usecols = 'A:K')
#print(df.shape)
#df.head()

count=0
cat=0

for i in range(df.shape[0]):
    
    gender=str(df['Gender'].iloc[i])
    
    if gender=='Female':
    
        score=(df['Digital health competency'].iloc[i])

        if score>=0.80:
            cat='Expert'
            #count=count+1

        elif score>=0.60 and score<0.80:
            cat='Proficient'
            #cat=4

        elif score>=0.40 and score<0.60:
            cat='Competent'
            #cat=3

        elif score>=0.20 and score<0.40:
            cat='Advanced'
            #cat=2

        else: 
            cat='Beginner'
            #cat=1


        count=count+1

        print(cat)
        #print("{}:{}".format(score,cat))

    
print(count)

"""

"""
# Import Data
excel_file="Potential of workforce.xlsx"
df=pd.read_excel(excel_file, sheet_name='calculation', usecols = 'A:K')
#print(df.shape)
#df.head()

count=0
cat=0

for i in range(df.shape[0]):
    
    loc=str(df['City'].iloc[i])
    
    if loc=='Outside City':
    
        #score=(df['Digital health competency'].iloc[i])
        
        score=(df['Psychological preparedness'].iloc[i])
        

        if score>=0.80:
            cat='Expert'
            #count=count+1

        elif score>=0.60 and score<0.80:
            cat='Proficient'
            #cat=4

        elif score>=0.40 and score<0.60:
            cat='Competent'
            #cat=3

        elif score>=0.20 and score<0.40:
            cat='Advanced'
            #cat=2

        else: 
            cat='Beginner'
            #cat=1


        count=count+1

        print(cat)
        #print("{}:{}".format(score,cat))

    
print(count)
"""

"""
# Import Data
excel_file="Potential of workforce.xlsx"
df=pd.read_excel(excel_file, sheet_name='calculation', usecols = 'A:K')
#print(df.shape)
#df.head()

count=0
cat=0

for i in range(df.shape[0]):
    
    loc=str(df['Public-private'].iloc[i])
    
    if loc=='Public':
    
        score=(df['Digital health competency'].iloc[i])
        
        #score=(df['Psychological preparedness'].iloc[i])
        

        if score>=0.80:
            cat='Expert'
            #count=count+1

        elif score>=0.60 and score<0.80:
            cat='Proficient'
            #cat=4

        elif score>=0.40 and score<0.60:
            cat='Competent'
            #cat=3

        elif score>=0.20 and score<0.40:
            cat='Advanced'
            #cat=2

        else: 
            cat='Beginner'
            #cat=1


        count=count+1

        print(cat)
        #print("{}:{}".format(score,cat))

    
print(count)
"""

# Import Data
excel_file="Potential of workforce.xlsx"
df=pd.read_excel(excel_file, sheet_name='calculation', usecols = 'A:K')
#print(df.shape)
#df.head()

count=0
cat=0

for i in range(df.shape[0]):
    
    age=str(df['Age'].iloc[i])
    
    if age=='35+':
    
        score=(df['Digital health competency'].iloc[i])
        
        #score=(df['Psychological preparedness'].iloc[i])
        

        if score>=0.80:
            cat='Expert'
            #count=count+1

        elif score>=0.60 and score<0.80:
            cat='Proficient'
            #cat=4

        elif score>=0.40 and score<0.60:
            cat='Competent'
            #cat=3

        elif score>=0.20 and score<0.40:
            cat='Advanced'
            #cat=2

        else: 
            cat='Beginner'
            #cat=1


        count=count+1

        print(cat)
        #print("{}:{}".format(score,cat))

    
print(count)
# Out:
# Competent
# Competent
# Proficient
# Competent
# Proficient
# Competent
# Proficient
# Competent
# Competent
# Competent
# Expert
# Competent
# Expert
# Competent
# Competent
# Proficient
# Proficient
# Proficient
# Expert
# Competent
# Proficient
# Proficient
# Competent
# Advanced
# Competent
# Proficient
# Proficient
# Advanced
# Competent
# Proficient
# Advanced
# Advanced
# Advanced
# Competent
# Advanced
# Proficient
# Competent
# Competent
# Expert
# Expert
# Proficient
# Expert
# Advanced
# Competent
# Competent
# Competent
# Competent
# Competent
# Competent
# Competent
# Competent
# Competent
# Advanced
# Advanced
# Competent
# Competent
# Beginner
# Advanced
# Expert
# Advanced
# Expert
# Competent
# Competent
# Competent
# Proficient
# Competent
# Competent
# Competent
# Competent
# Advanced
# Advanced
# Proficient
# Proficient
# Competent
# Competent
# Advanced
# Competent
# Competent
# Advanced
# Advanced
# Proficient
# Competent
# Competent
# Advanced
# Competent
# ...
