# %%
import pandas as pd
import plot_likert
import numpy as np
import matplotlib.pyplot as plt

excel_file="Analysis of Q14.xlsx"

df=pd.read_excel(excel_file, sheet_name='calculation', usecols = 'A:I')


#print(df.shape)

df.head()


vg_count=0
g_count=0
p_count=0
r_count=0
vr_count=0


for i in range(df.shape[0]):
    
    will=str(df['Want to transform'].iloc[i])
    
    
    #role=str(df['Role'].iloc[i])

    if will=="Very gladly":
        vg_count=vg_count+1
    
    elif will=="Gladly":
        g_count=g_count+1
        
    elif will=="Partly":
        p_count=p_count+1
    
    elif will=="Reluctantly":
        r_count=r_count+1
    else:
        vr_count=vr_count+1
        
    
 

print(vg_count)
print(g_count)
print(p_count)
print(r_count)
print(vr_count)





#identify professional distribution of each each type

student_count=0
doctor_count=0
patho_count=0
rad_count=0
tech_count=0

for i in range(df.shape[0]):
    
    will=str(df['Want to transform'].iloc[i])
    
    
    #role=str(df['Role'].iloc[i])

    #if will=="Very gladly":
        
    #if will=="Gladly":
        
    #if will=="Partly":
    
    #if will=="Reluctantly":
    
    if will=="Very reluctantly":
        role=str(df['Role'].iloc[i])
        
        if role=="Student":
            student_count=student_count+1
            #print(student_count)
            
        elif role=="Doctor/physician":
             doctor_count=doctor_count+1
            
            
        elif role=="Pathologist":
             patho_count=patho_count+1    
        
            
        elif role=="Radiologist":
             rad_count=rad_count+1

                            
        elif role=="Technician":
             tech_count=tech_count+1


print("student:{}".format(student_count))
print("doctors:{}".format(doctor_count))
print("pathologist:{}".format(patho_count))
print("radiologist:{}".format(rad_count))
print("technician:{}".format(tech_count))
# Out:
# 81
# 166
# 221
# 187
# 46
# student:16
# doctors:18
# pathologist:3
# radiologist:7
# technician:2
